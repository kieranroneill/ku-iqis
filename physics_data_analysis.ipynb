# %%
import libs
import pandas as pd

# %% [markdown]
# # Physics: Basic Quantum Optics Experiments
#
# ## 1. Polarization of single photons
#
# ### 1.1 Default half-wave plate

# %%
default_data_file_path = "data/physics/polarization_of_single_photons-default.xlsx"
single_zero_data = pd.read_excel(default_data_file_path, sheet_name="single_zero_count_rate", index_col=0)
single_one_data = pd.read_excel(default_data_file_path, sheet_name="single_one_count_rate", index_col=0)
coincidences_data = pd.read_excel(default_data_file_path, sheet_name="coincidences_count_rate", index_col=0)

# %%
libs.plot_optics_coincidence_heatmap(coincidences_data)

# %% [markdown]
# ### 1.2. Rotated half-wave plate

# %%
default_data_file_path = "data/physics/polarization_of_single_photons-half_wave_plate_rotation.xlsx"
single_zero_data = pd.read_excel(default_data_file_path, sheet_name="single_zero_count_rate", index_col=0)
single_one_data = pd.read_excel(default_data_file_path, sheet_name="single_one_count_rate", index_col=0)
coincidences_data = pd.read_excel(default_data_file_path, sheet_name="coincidences_count_rate", index_col=0)

# %%
libs.plot_optics_coincidence_heatmap(coincidences_data)
